# %% [markdown]
# 남자

# %%
from selenium import webdriver
from bs4 import BeautifulSoup as soups
import os
import time
import urllib.request
from selenium.webdriver.common.keys import Keys

def search_selenium(search_name,save_name , page) :
     
    woman = ['http://browse.auction.co.kr/list?category=13070000','http://browse.auction.co.kr/list?category=13290000','http://browse.auction.co.kr/list?category=13050000',
              'http://browse.auction.co.kr/list?category=13090000','http://browse.auction.co.kr/list?category=13130000','http://browse.auction.co.kr/list?category=13100000',
              'http://browse.auction.co.kr/list?category=13260000','http://browse.auction.co.kr/list?category=13240000','http://browse.auction.co.kr/list?category=13250000',
            'http://browse.auction.co.kr/list?category=13120000']
    
    page += 1
    MODEL_DIR = 'E:\이미지\{}'.format(save_name)
    
    if not os.path.exists(MODEL_DIR):    
        os.mkdir(MODEL_DIR)
        
    search_url = woman[search_clothes]
        
    driver = webdriver.Chrome('C:\chromedriver\chromedriver.exe')
    driver.get(search_url)
    
    SCROLL_PAUSE_SEC = 1

    
    num = 2 # 페이지 넘김
    index = 1 # 저장 번호 index
    for i in range(page):
        page_src = []
        while True:

            driver.execute_script("window.scrollTo(0, window.scrollY + 600);")
            time.sleep(SCROLL_PAUSE_SEC)
            image_count = len(driver.find_elements_by_class_name("image--itemcard  "))
            images = driver.find_elements_by_class_name("image--itemcard  ")
            print(image_count)  
            
            if image_count == 100:
                
#                 if (search_clothes == 7) or (search_clothes == 8):
#                     for image in images:
#                         image_url = image.get_attribute('src')
#                         urllib.request.urlretrieve(image_url, MODEL_DIR +"\{}_{}.jpg".format(save_name,index))
#                         index += 1

#                     driver.find_element_by_link_text("{}".format(num)).send_keys(Keys.ENTER)
#                     num += 1
#                     break
                    
#                 else : 
                for image in images:
                    image_url = image.get_attribute('src')
                    urllib.request.urlretrieve(image_url, MODEL_DIR +"\{}_{}.jpg".format(save_name,index))
                    index += 1

                driver.find_element_by_link_text("{}".format(num)).click()
                num += 1
                break
            
            if num > page:
                break
                
        if num > page:
            break

    driver.close()
    

if __name__ == "__main__" :
    
    search_clothes = int(input('니트(0),반팔티셔츠(1),긴팔티셔츠(2),점퍼/야상/패딩(3),코트(4),자켓(5),청바지(6),긴바지(7),반바지(8),트레이닝복(9) : '))
    save_name = input("저장하고 싶은 이름 : ")
    page = int(input("페이지 : "))
    
    # search_maybe(search_name, search_limit, search_path)

search_selenium(search_clothes,save_name,page)
# Out:
# 니트(0),반팔티셔츠(1),긴팔티셔츠(2),점퍼/야상/패딩(3),코트(4),자켓(5),청바지(6),긴바지(7),반바지(8),트레이닝복(9) :  0
# 저장하고 싶은 이름 :  남자니트
# 페이지 :  2
# 7
# 9
# 12
# 15
# 17
# 20
# 22
# 25
# 28
# 31
# 33
# 36
# 39
# 41
# 44
# 47
# 50
# 52
# 55
# 58
# 60
# 63
# 66
# 69
# 71
# 74
# 77
# 79
# 82
# 85
# 88
# 90
# 93
# 96
# 98
# 100
# 7
# 10
# 12
# 15
# 18
# 21
# 23
# 26
# 29
# 31
# 34
# 37
# 40
# 42
# 45
# 48
# 50
# 53
# 56
# 59
# 61
# 64
# 67
# 69
# 72
# 75
# 78
# 80
# 83
# 86
# 88
# 91
# 94
# 97
# 99
# 100

# %% [markdown]
# 여자

# %%
from selenium import webdriver
from bs4 import BeautifulSoup as soups
import os
import time
import urllib.request
from selenium.webdriver.common.keys import Keys

def search_selenium(search_name,save_name , page) :
     
    woman = ['http://browse.auction.co.kr/list?category=12080000','http://browse.auction.co.kr/list?category=12070000','http://browse.auction.co.kr/list?category=12050000',
              'http://browse.auction.co.kr/list?category=12140000','http://browse.auction.co.kr/list?category=12220000','http://browse.auction.co.kr/list?category=12380000',
              'http://browse.auction.co.kr/list?category=12150000','http://browse.auction.co.kr/list?category=12230000','http://browse.auction.co.kr/list?category=12370000',
            'http://browse.auction.co.kr/list?category=12090000','http://browse.auction.co.kr/list?category=12130000','http://browse.auction.co.kr/list?category=12390000']
    
    page += 1
    MODEL_DIR = 'E:\이미지\{}'.format(save_name)
    
    if not os.path.exists(MODEL_DIR):    
        os.mkdir(MODEL_DIR)
        
    search_url = woman[search_clothes]
        
    driver = webdriver.Chrome('C:\chromedriver\chromedriver.exe')
    driver.get(search_url)
    
    SCROLL_PAUSE_SEC = 1

    
    num = 2 # 페이지 넘김
    index = 1 # 저장 번호 index
    for i in range(page):
        page_src = []
        while True:

            driver.execute_script("window.scrollTo(0, window.scrollY + 600);")

            image_count = len(driver.find_elements_by_class_name("image--itemcard  "))
            images = driver.find_elements_by_class_name("image--itemcard  ")
            print(image_count)  
            
            if image_count == 100:
                
                if (search_clothes == 7) or (search_clothes == 8):
                    for image in images:
                        image_url = image.get_attribute('src')
                        urllib.request.urlretrieve(image_url, MODEL_DIR +"\{}_{}.jpg".format(save_name,index))
                        index += 1

                    driver.find_element_by_link_text("{}".format(num)).send_keys(Keys.ENTER)
                    num += 1
                    break
                    
                else : 
                    for image in images:
                        image_url = image.get_attribute('src')
                        urllib.request.urlretrieve(image_url, MODEL_DIR +"\{}_{}.jpg".format(save_name,index))
                        index += 1

                    driver.find_element_by_link_text("{}".format(num)).click()
                    num += 1
                    break
            
            if num > page:
                break
                
        if num > page:
            break

    driver.close()
    

if __name__ == "__main__" :
    
    search_clothes = int(input('티셔츠(0),원피스(1),셔츠/블라우스(2),바지(3),청바지(4),레깅스(5),트레이닝복(6),자켓/코트(7),점퍼/야상/패딩(8),니트(9),스커트(10),정장(11) : '))
    save_name = input("저장하고 싶은 이름 : ")
    page = int(input("페이지 : "))
    
    # search_maybe(search_name, search_limit, search_path)

search_selenium(search_clothes,save_name,page)
# Out:
# 티셔츠(0),원피스(1),셔츠/블라우스(2),바지(3),청바지(4),레깅스(5),트레이닝복(6),자켓/코트(7),점퍼/야상/패딩(8),니트(9),스커트(10),정장(11) :  0
# 저장하고 싶은 이름 :  여자티셔츠
# 페이지 :  2
# 5
# 5
# 8
# 13
# 16
# 18
# 18
# 21
# 23
# 29
# 31
# 31
# 34
# 37
# 39
# 45
# 48
# 48
# 50
# 53
# 59
# 59
# 64
# 67
# 69
# 72
# 72
# 78
# 78
# 80
# 86
# 86
# 88
# 94
# 94
# 97
# 99
# 100
# 4
# 7
# 10
# 15
# 18
# 18
# 21
# 23
# 29
# 29
# 31
# 34
# 40
# 40
# 45
# 45
# 48
# 53
# 53
# 56
# 61
# 61
# 64
# 69
# 72
# 72
# 75
# 78
# 83
# 86
# 86
# 88
# 91
# 94
# 97
# 99
# 100
